# %% [markdown]
# # Cubic Spline Interpolation

# %%
from scipy import interpolate
import numpy as np
import matplotlib.pyplot as plt

# %%
def myfunc(x): return 1/(1+x*x)

pts = np.linspace(-5, 5, 21)
vals = myfunc(pts)
print (pts, vals)
# Out:
# [-5.  -4.5 -4.  -3.5 -3.  -2.5 -2.  -1.5 -1.  -0.5  0.   0.5  1.   1.5
#   2.   2.5  3.   3.5  4.   4.5  5. ] [0.03846154 0.04705882 0.05882353 0.0754717  0.1        0.13793103
#  0.2        0.30769231 0.5        0.8        1.         0.8
#  0.5        0.30769231 0.2        0.13793103 0.1        0.0754717
#  0.05882353 0.04705882 0.03846154]

# %%
tck = interpolate.splrep(pts, vals)
x = np.linspace(-5,5,100)
plt.plot (x, myfunc(x), x, interpolate.splev(x, tck), pts, vals, "x")
# Out:
# [<matplotlib.lines.Line2D at 0x1edd179b5b0>,
#  <matplotlib.lines.Line2D at 0x1edd179b430>,
#  <matplotlib.lines.Line2D at 0x1edd179b700>]

# %% [markdown]
# compare spline interplant with polynomial interpolation

# %%
poly = interpolate.lagrange(pts, vals)
plt.ylim(-1, 2)
plt.plot (x, myfunc(x), x, interpolate.splev(x, tck), x, poly(x), pts, vals, "x")
# Out:
# [<matplotlib.lines.Line2D at 0x1edd1ad2910>,
#  <matplotlib.lines.Line2D at 0x1edd1ad2a00>,
#  <matplotlib.lines.Line2D at 0x1edd1ad28e0>,
#  <matplotlib.lines.Line2D at 0x1edd1ad2b80>]

# %% [markdown]
# spline interpolation easily allows local refinement of knots:

# %%
a = 100
pts = a * np.linspace(-1,1,30)**3
vals = myfunc(pts)
tck = interpolate.splrep(pts, vals)

x = np.linspace(-a,a,1000)
plt.xlim(-a,a)
plt.plot (x, myfunc(x), x, interpolate.splev(x, tck), pts, vals, "x")
# Out:
# [<matplotlib.lines.Line2D at 0x1edd1b411f0>,
#  <matplotlib.lines.Line2D at 0x1edd1b410a0>,
#  <matplotlib.lines.Line2D at 0x1edd1b41370>]

# %% [markdown]
# the spline is represented as a B-spline:  knots t, coefficients s, order k

# %%
print (tck)
# Out:
# (array([-1.00000000e+02, -1.00000000e+02, -1.00000000e+02, -1.00000000e+02,
#        -6.40657674e+01, -4.98872442e+01, -3.79720366e+01, -2.81233343e+01,
#        -2.01443274e+01, -1.38382057e+01, -9.00815942e+00, -5.45737833e+00,
#        -2.98905244e+00, -1.40637172e+00, -5.12526139e-01, -1.10705646e-01,
#        -4.10020911e-03,  4.10020911e-03,  1.10705646e-01,  5.12526139e-01,
#         1.40637172e+00,  2.98905244e+00,  5.45737833e+00,  9.00815942e+00,
#         1.38382057e+01,  2.01443274e+01,  2.81233343e+01,  3.79720366e+01,
#         4.98872442e+01,  6.40657674e+01,  1.00000000e+02,  1.00000000e+02,
#         1.00000000e+02,  1.00000000e+02]), array([9.99900010e-05, 1.10870337e-04, 1.91556369e-04, 3.32338625e-04,
#        7.13304551e-04, 8.36387381e-04, 2.79316544e-03, 2.32477285e-03,
#        1.39181051e-02, 1.17461140e-02, 8.62761333e-02, 1.53499972e-01,
#        6.84790759e-01, 9.80816127e-01, 1.00000494e+00, 1.00000494e+00,
#        9.80816127e-01, 6.84790759e-01, 1.53499972e-01, 8.62761333e-02,
#        1.17461140e-02, 1.39181051e-02, 2.32477285e-03, 2.79316544e-03,
#        8.36387381e-04, 7.13304551e-04, 3.32338625e-04, 1.91556369e-04,
#        1.10870337e-04, 9.99900010e-05, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00]), 3)

# %%
print (pts)
# Out:
# [-1.00000000e+02 -8.07044159e+01 -6.40657674e+01 -4.98872442e+01
#  -3.79720366e+01 -2.81233343e+01 -2.01443274e+01 -1.38382057e+01
#  -9.00815942e+00 -5.45737833e+00 -2.98905244e+00 -1.40637172e+00
#  -5.12526139e-01 -1.10705646e-01 -4.10020911e-03  4.10020911e-03
#   1.10705646e-01  5.12526139e-01  1.40637172e+00  2.98905244e+00
#   5.45737833e+00  9.00815942e+00  1.38382057e+01  2.01443274e+01
#   2.81233343e+01  3.79720366e+01  4.98872442e+01  6.40657674e+01
#   8.07044159e+01  1.00000000e+02]
