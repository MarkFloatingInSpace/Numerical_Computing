# %% [markdown]
# Calculate the LU decomposition of the matrix
#
# $$ A= \left(\begin{array}{cc}
# 10^{-6} & 1\\
# 1 & 0
# \end{array}\right) $$
#
# by hand.  Find a normalized lower left triangular matrix L and an upper right trian-gular matrix U such that $A=LU$. Furthermore, calculate $A^{−1}$, $L^{−1}$, and $U^{−1}$, and the condition numbers
# $$cond_\infty(M) =‖M‖_\infty‖M^{−1}‖_\infty$$
#
# for all of these matrices.
#
# The maximum absolute row sum norm (Zeilenbetragssum-mennorm) is defined as
# $$ ‖M‖_\infty=  max_{i=1,...n} \sum_{j=1}^n |M_{i,j}| $$
#
# Then, swap the rows of A and repeat the calculations.

# %% [markdown]
# $$ \left(\begin{array}{cc}
# 1 & 0\\
# l_{2 1} & 1
# \end{array}\right)
# \left(\begin{array}{cc}
# u_{1 1} & u_{1 2}\\
# 0 & u_{2 2}
# \end{array}\right) =
# \left(\begin{array}{cc}
# 10^{-6} & 1\\
# 1 & 0
# \end{array}\right)$$
#
# The first row of U is the first column of A.
#
# $$ \left(\begin{array}{cc}
# 1 & 0\\
# l_{2 1} & 1
# \end{array}\right)
# \left(\begin{array}{cc}
# 10^{-6} & 1\\
# 0 & u_{2 2}
# \end{array}\right) =
# \left(\begin{array}{cc}
# 10^{-6} & 1\\
# 1 & 0
# \end{array}\right)$$
#
# Next calculate the second row of L using th first row of U.
# $$ l_{2 1} \cdot 10^{-6} = 1 $$
#
# $$ \left(\begin{array}{cc}
# 1 & 0\\
# 10^6 & 1
# \end{array}\right)
# \left(\begin{array}{cc}
# 10^{-6} & 1\\
# 0 & u_{2 2}
# \end{array}\right) =
# \left(\begin{array}{cc}
# 10^{-6} & 1\\
# 1 & 0
# \end{array}\right)$$
#
# Calculate the second column of U using the second row of L.
#
# $$ \left(\begin{array}{cc}
# 1 & 0\\
# 10^6 & 1
# \end{array}\right)
# \left(\begin{array}{cc}
# 10^{-6} & 1\\
# 0 & -10^6
# \end{array}\right) =
# \left(\begin{array}{cc}
# 10^{-6} & 1\\
# 1 & 0
# \end{array}\right)$$
#
# ... repeat until finished.

# %% [markdown]
# $$ A^{-1} = \left(\begin{array}{cc}
# 0 & 1\\
# 1 & -10^{-6}
# \end{array}\right) $$
#
#
# $$ L^{-1} = \left(\begin{array}{cc}
# 1 & 0\\
# -10^{6} & 1
# \end{array}\right) $$
#
# $$ U^{-1} = \left(\begin{array}{cc}
# 10^{6} & -1\\
# 0 & -10^{6}
# \end{array}\right) $$

# %% [markdown]
# $$cond_\infty(M) =‖M‖_\infty‖M^{−1}‖_\infty$$
#
# $$ cond_\infty(A) = (1+10^{-6})(1+10^{-6}) = 1 + 2*10^{-6} + 10^{-12} $$
#
# $$ cond_\infty(L) = (1+10^{6})(1+10^{6}) = 1 + 10^{12} + 2*10^{6} + 1 $$
#
# $$ cond_\infty(U) = (1+10^{-6})(1+10^{6}) = 10^{12} + 10^6 $$

# %% [markdown]
# ## Swapping the rows of A
# $$ A= \left(\begin{array}{cc}
# 1 & 0\\
# 10^{-6} & 1
# \end{array}\right) $$
#
#
# $$ \left(\begin{array}{cc}
# 1 & 0\\
# l_{2 1} & 1
# \end{array}\right)
# \left(\begin{array}{cc}
# u_{1 1} & u_{1 2}\\
# 0 & u_{2 2}
# \end{array}\right) =
# \left(\begin{array}{cc}
# 1 & 0 \\
# 10^{-6} & 1
# \end{array}\right)$$
#
# $$ \left(\begin{array}{cc}
# 1 & 0\\
# l_{2 1} & 1
# \end{array}\right)
# \left(\begin{array}{cc}
# 1 & 0\\
# 0 & u_{2 2}
# \end{array}\right) =
# \left(\begin{array}{cc}
# 1 & 0 \\
# 10^{-6} & 1
# \end{array}\right)$$
#
# $$ \left(\begin{array}{cc}
# 1 & 0\\
# 10^{-6} & 1
# \end{array}\right)
# \left(\begin{array}{cc}
# 1 & 0\\
# 0 & u_{2 2}
# \end{array}\right) =
# \left(\begin{array}{cc}
# 1 & 0 \\
# 10^{-6} & 1
# \end{array}\right)$$
#
# $$ \left(\begin{array}{cc}
# 1 & 0\\
# 10^{-6} & 1
# \end{array}\right)
# \left(\begin{array}{cc}
# 1 & 0\\
# 0 & 1
# \end{array}\right) =
# \left(\begin{array}{cc}
# 1 & 0 \\
# 10^{-6} & 1
# \end{array}\right)$$
#
# Because A is already a trinagle matrix, the LU decomposition has no effect and either the L or U matrix becomes the identity matrix

# %% [markdown]
# $$ A^{-1} = L^{-1} = \left(\begin{array}{cc}
# 1 & 0\\
# -10^{-6} & 1
# \end{array}\right) $$
#
#
# $$ U^{-1} = U $$

# %% [markdown]
# $$cond_\infty(M) =‖M‖_\infty‖M^{−1}‖_\infty$$
#
# $$ cond_\infty(A) = cond_\infty(L) = (1+10^{-6})(1+10^{-6}) = 1 + 2*10^{-6} + 10^{-12} $$
#
# $$ cond_\infty(U) = 1 $$
